# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\91948\Desktop\projects\ml and python projects\fifa project\players_20.csv")
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
df['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
df['nationality'].value_counts()[0:10] #seeing top ten players from the world
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
plt.bar(list(df['nationality'].value_counts()[0:5].keys()),list(df['nationality'].value_counts()[0:5]),color='y')
plt.figure(figsize=(15,30))

# %% [markdown]
# here we can see england has  most players who palayed in fifa followed by brazil

# %% [markdown]
# # checking top 10 highest paid salary in fifa to players

# %%
players_salary = df[['short_name','wage_eur']]

# %%
players_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %% [markdown]
# sorting wage_eur in ascending format

# %%
player_salary = players_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color='b')
plt.figure(figsize=(8,5))

# %% [markdown]
# here we can observe hazard is paid more wages then cr7 this is great insight

# %% [markdown]
# # doing some sought of analysis on particular country

# %% [markdown]
# england

# %%
df['nationality']=='england'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
England = df[df['nationality']=='England']
England.head()
# Out:
#      sofifa_id                                         player_url  \
# 12      202126  https://sofifa.com/player/202126/harry-kane/20...
# 26      202652  https://sofifa.com/player/202652/raheem-sterli...
# 108     233049  https://sofifa.com/player/233049/jadon-sancho/...
# 113     211117  https://sofifa.com/player/211117/dele-alli/20/...
# 148     188377  https://sofifa.com/player/188377/kyle-walker/2...
#
#       short_name        long_name  age         dob  height_cm  weight_kg  \
# 12       H. Kane       Harry Kane   25  1993-07-28        188         89
# 26   R. Sterling  Raheem Sterling   24  1994-12-08        170         69
# 108    J. Sancho     Jadon Sancho   19  2000-03-25        180         76
# 113      D. Alli    Bamidele Alli   23  1996-04-11        188         80
# 148    K. Walker      Kyle Walker   29  1990-05-28        183         70
#
#     nationality               club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
# checking talest player
England.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 12808     215408  https://sofifa.com/player/215408/aaron-chapman...
# 17365     241870  https://sofifa.com/player/241870/matt-casey/20...
# 3014      172203  https://sofifa.com/player/172203/fraser-forste...
# 628       203841  https://sofifa.com/player/203841/nick-pope/20/...
# 11526     223069  https://sofifa.com/player/223069/omar-sowunmi/...
#
#        short_name       long_name  age         dob  height_cm  weight_kg  \
# 12808  A. Chapman   Aaron Chapman   29  1990-05-29        203         92
# 17365    M. Casey      Matt Casey   19  1999-11-13        203         80
# 3014   F. Forster  Fraser Forster   31  1988-03-17        201         93
# 628       N. Pope       Nick Pope   27  1992-04-19        200         76
# 11526  O. Sowunmi    Omar Sowunmi   23  1995-11-07        199         93
#
#       nationality                 club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
England[['short_name','height_cm']].sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        short_name  height_cm
# 12808  A. Chapman        203
# 17365    M. Casey        203
# 3014   F. Forster        201
# 628       N. Pope        200
# 11526  O. Sowunmi        199

# %% [markdown]
# here we can observe that a.chapman is talenst player in england football team

# %%
# checking oldest player in england 
England.sort_values(by=['age'],ascending = False).head()
# Out:
#        sofifa_id                                         player_url  \
# 14527      53352  https://sofifa.com/player/53352/dannie-bulman/...
# 16314       2702  https://sofifa.com/player/2702/kevin-ellison/2...
# 13778       2335  https://sofifa.com/player/2335/aaron-wilbraham...
# 8369      151270  https://sofifa.com/player/151270/james-copping...
# 13785      54008  https://sofifa.com/player/54008/stephen-bywate...
#
#          short_name        long_name  age         dob  height_cm  weight_kg  \
# 14527     D. Bulman    Dannie Bulman   40  1979-01-24        175         75
# 16314    K. Ellison    Kevin Ellison   40  1979-02-23        180         76
# 13778  A. Wilbraham  Aaron Wilbraham   39  1979-10-21        191         80
# 8369   J. Coppinger  James Coppinger   38  1981-01-10        170         65
# 13785    S. Bywater  Stephen Bywater   38  1981-06-07        185         81
#
#       nationality              club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %% [markdown]
# here d bulman and k.ellison is oldest player of england

# %%
# let us check which player has got highest wages in england as per fifa
England.sort_values(by=['wage_eur'], ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 26      202652  https://sofifa.com/player/202652/raheem-sterli...
# 12      202126  https://sofifa.com/player/202126/harry-kane/20...
# 148     188377  https://sofifa.com/player/188377/kyle-walker/2...
# 172     203574  https://sofifa.com/player/203574/john-stones/2...
# 319     207494  https://sofifa.com/player/207494/jesse-lingard...
#
#       short_name        long_name  age         dob  height_cm  weight_kg  \
# 26   R. Sterling  Raheem Sterling   24  1994-12-08        170         69
# 12       H. Kane       Harry Kane   25  1993-07-28        188         89
# 148    K. Walker      Kyle Walker   29  1990-05-28        183         70
# 172    J. Stones      John Stones   25  1994-05-28        188         70
# 319   J. Lingard    Jesse Lingard   26  1992-12-15        175         62
#
#     nationality               club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
England[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#       short_name  wage_eur
# 26   R. Sterling    255000
# 12       H. Kane    220000
# 148    K. Walker    165000
# 172    J. Stones    140000
# 319   J. Lingard    135000

# %% [markdown]
# here we can observe r.sterling is highest paid footballer in england folowed by h.kane

# %% [markdown]
# like this we can check status of each country

# %% [markdown]
# # now let us check rating of palyer based upon their shooting skills

# %%
df[['short_name','shooting','club']].sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting               club
# 1    Cristiano Ronaldo      93.0           Juventus
# 0             L. Messi      92.0       FC Barcelona
# 12             H. Kane      91.0  Tottenham Hotspur
# 17           S. Agüero      90.0    Manchester City
# 205    F. Quagliarella      89.0          Sampdoria

# %% [markdown]
#  here we can see c.ronaldo has givien best shooting skills rating aroung 93% followed by l.messi 92%

# %% [markdown]
# now let us check rating of players on their defending skills

# %%
df[['short_name','defending','club']].sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending               club
# 16  G. Chiellini       90.0           Juventus
# 7    V. van Dijk       90.0          Liverpool
# 11  K. Koulibaly       89.0             Napoli
# 35      D. Godín       89.0              Inter
# 49    M. Hummels       89.0  Borussia Dortmund

# %% [markdown]
#  here we can see g.chiellini and van dijk has got highest rating on around 90%

# %% [markdown]
# #  now let us check status of club

# %% [markdown]
# using fc barcelona club data

# %%
 df[df['club']=='FC Barcelona'].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 22     194765  https://sofifa.com/player/194765/antoine-griez...
# 19     176580  https://sofifa.com/player/176580/luis-suarez/2...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
#
#          short_name                       long_name  age         dob  \
# 0          L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24
# 22     A. Griezmann               Antoine Griezmann   28  1991-03-21
# 19        L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24
# 21  Sergio Busquets        Sergio Busquets i Burgos   30  1988-07-16
# 29            Piqué           Gerard Piqué Bernabéu   32  1987-02-02
#
#     height_cm  weight_kg nationality          club  ...   lwb   ldm   cdm  \
# 0         170         72   Argentina  FC Barcelona  ...  68+2  66+2  66+2
# ...

# %% [markdown]
# here we can observe that l.messi is highest paid players in fc barcelona club

# %%
df[df['club']=='FC Barcelona'].sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...
# 19      176580  https://sofifa.com/player/176580/luis-suarez/2...
# 22      194765  https://sofifa.com/player/194765/antoine-griez...
# 64      168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#        short_name                       long_name  age         dob  height_cm  \
# 0        L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# 19      L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24        182
# 22   A. Griezmann               Antoine Griezmann   28  1991-03-21        176
# 64     I. Rakitić                    Ivan Rakitić   31  1988-03-10        184
# 142      A. Vidal                    Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %% [markdown]
# in case of shooting skills also messi is in top followed by l.saurez

# %%
df[df['club']=='FC Barcelona'].sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 29      152729  https://sofifa.com/player/152729/gerard-pique-...
# 84      220440  https://sofifa.com/player/220440/clement-lengl...
# 59      205600  https://sofifa.com/player/205600/samuel-umtiti...
# 21      189511  https://sofifa.com/player/189511/sergio-busque...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#           short_name                 long_name  age         dob  height_cm  \
# 29             Piqué     Gerard Piqué Bernabéu   32  1987-02-02        194
# 84        C. Lenglet           Clément Lenglet   24  1995-06-17        186
# 59         S. Umtiti             Samuel Umtiti   25  1993-11-14        182
# 21   Sergio Busquets  Sergio Busquets i Burgos   30  1988-07-16        189
# 142         A. Vidal              Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %% [markdown]
#  in case of defending pique on top
